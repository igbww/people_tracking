# %%
# !git clone https://github.com/NS19972/FairMOT.git
# Out:
# Cloning into 'FairMOT'...
# remote: Enumerating objects: 731, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 731 (delta 6), reused 5 (delta 1), pack-reused 719
# Receiving objects: 100% (731/731), 63.34 MiB | 16.35 MiB/s, done.
# Resolving deltas: 100% (389/389), done.

# %%
#!pip install torch==1.7.0 
#!pip install torchvision==0.8.0 
# !pip install torch==1.7.1 
# !pip install torchvision==0.8.2
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.7.1 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.7.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.7.1 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.7.1 which is incompatible.
# ...

# %%
# %cd FairMOT
# !pip install -r requirements.txt
# Out:
# /content/FairMOT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 81.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cython-bbox: filename=cython_bbox-0.1.3-cp39-cp39-linux_x86_64.whl size=66772 sha256=375a2cfeab914576be49cbe5e43f074d8669bcfb6fc056ae7fb17c9c1533ca1c
# ...

# %%
# !git clone -b pytorch_1.7 https://github.com/ifzhang/DCNv2.git
# %cd DCNv2
# !./make.sh
# Out:
# Cloning into 'DCNv2'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 263 (delta 94), reused 76 (delta 76), pack-reused 153
# Receiving objects: 100% (263/263), 1.42 MiB | 21.64 MiB/s, done.
# Resolving deltas: 100% (169/169), done.
# /content/FairMOT/DCNv2
# running build
# running build_ext
# /usr/local/lib/python3.9/dist-packages/torch/utils/cpp_extension.py:352: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# building '_ext' extension
# creating build
# creating build/temp.linux-x86_64-3.9
# creating build/temp.linux-x86_64-3.9/content
# creating build/temp.linux-x86_64-3.9/content/FairMOT
# creating build/temp.linux-x86_64-3.9/content/FairMOT/DCNv2
# creating build/temp.linux-x86_64-3.9/content/FairMOT/DCNv2/src
# ...

# %%
# !pip install -U --no-cache-dir gdown --pre
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...

# %%
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# Загружаем папку src предыдущая версия беp архитектуры yolo5s
#!gdown --no-cookies --fuzzy https://drive.google.com/file/d/1CSgW7tkF9ZJNxq17hioithaix3vu_ctU/view?usp=share_link&export=download

# Загружаем папку src c архитектурой yolo5s
# !gdown --no-cookies --fuzzy  https://drive.google.com/file/d/1fnedh52yKmKbA8nNtdUY85VUNy0a44_R/view?usp=share_link&export=download

# Загружаем датасет
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1qDJK7S5OlxbMQPnU43WsgyCgOas-QwGP/view?usp=share_link&export=download
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fnedh52yKmKbA8nNtdUY85VUNy0a44_R
# To: /content/src_last.zip
# 100% 2.48M/2.48M [00:00<00:00, 81.0MB/s]
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1qDJK7S5OlxbMQPnU43WsgyCgOas-QwGP
# From (redirected): https://drive.google.com/uc?id=1qDJK7S5OlxbMQPnU43WsgyCgOas-QwGP&confirm=t&uuid=0d81d7ec-18fa-4095-b16d-a61572a61b59
# To: /content/datasetC5.zip
# 100% 466M/466M [00:16<00:00, 28.6MB/s]

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# **ОБЯЗАТЕЛЬНО ПЕРЕИМЕНОВЫВВАЕМ ПАПКУ src в папке FairMOT, после этого запускаем дальше ячейки**

# %%
#!unzip "/content/src (2).zip" -d "/content/FairMOT"
# !unzip "/content/src_last.zip" -d "/content/FairMOT"

# %%
# !unzip "/content/datasetC5.zip" -d "/content/FairMOT"

# %%
# %cd /content/FairMOT
# Out:
# /content/FairMOT

# %% [markdown]
# **Формирование лейблов уже выполнено этот файл запускать не нужно**

# %%
# формирование labels
#!python /content/FairMOT/src/gen_labels_mot16_cvat.py
# Out:
# Dir /content/FairMOT/datasetC5/labels_with_ids made
# Process val, 0
# Traceback (most recent call last):
#   File "/content/FairMOT/src/gen_labels_mot16_cvat.py", line 57, in <module>
#     gt = np.loadtxt(gt_txt, dtype=np.float64, delimiter=',')  # 加载成np格式   загрузить в формате np
#   File "/usr/local/lib/python3.9/dist-packages/numpy/lib/npyio.py", line 1042, in loadtxt
#     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#   File "/usr/local/lib/python3.9/dist-packages/numpy/lib/_datasource.py", line 193, in open
#     return ds.open(path, mode, encoding=encoding, newline=newline)
#   File "/usr/local/lib/python3.9/dist-packages/numpy/lib/_datasource.py", line 532, in open
#     raise FileNotFoundError(f"{path} not found.")
# FileNotFoundError: /content/FairMOT/datasetC5/images/val/gt/gt.txt not found.

# %% [markdown]
# **Сдесь запускаем дальше**

# %%
import os
import pandas as pd
train_dir = '/content/FairMOT/datasetC5/images/train/'
val_dir = '/content/FairMOT/datasetC5/images/val/'

training_files = os.listdir('/content/FairMOT/datasetC5/images/train/')
val_files = os.listdir('/content/FairMOT/datasetC5/images/val/')

training_df = pd.DataFrame(training_files,columns=['images'])
training_df.images = training_df.images.map(lambda x: train_dir + x)
val_df = pd.DataFrame(val_files,columns=['images'])
val_df.images = val_df.images.map(lambda x: val_dir + x)

# %%
# %cd /content/FairMOT
# Out:
# /content/FairMOT

# %%
# Сгенерируйте файлы, содержащие пути к изображениям, и сохраните их в src/data.
train_file = 'src/data/C5.train'
test_file = 'src/data/C5.val'
with open(train_file, 'w') as f:
    f.write("\n".join(training_df.images.values))
with open(test_file, 'w') as f:
    f.write("\n".join(val_df.images.values))

# %%
# Создайте файл json для набора данных в src/lib/cfg/
import json
train_file = 'src/data/C5.train'
test_file  = 'src/data/C5.val'
cfg = dict(
    root='/content/FairMOT/datasetC5',
    train=dict(C5_train=train_file),
    test=dict(C5_test=test_file),
    test_emb=dict(C5_test=test_file),
)
with open('src/lib/cfg/C5.json', 'w') as f:
    json.dump(cfg, f, indent=4)

# %% [markdown]
# **Запускаем обучение**

# %%
# %cd /content/FairMOT/
# !python src/train_val.py --task mot --arch resdcn_18  --gpus 0 --batch_size 8 --num_epochs 100 --lr_step '50' --data_cfg '/content/FairMOT/src/lib/cfg/C5.json'
# Out:
# /content/FairMOT
# Using tensorboardX
# 2023-04-05 04:19:30 [DEBUG]: matplotlib data path: /usr/local/lib/python3.9/dist-packages/matplotlib/mpl-data
# 2023-04-05 04:19:30 [DEBUG]: CONFIGDIR=/root/.config/matplotlib
# 2023-04-05 04:19:30 [DEBUG]: interactive is False
# 2023-04-05 04:19:30 [DEBUG]: platform is linux
# 2023-04-05 04:19:30 [DEBUG]: CACHEDIR=/root/.cache/matplotlib
# 2023-04-05 04:19:30 [DEBUG]: Using fontManager instance from /root/.cache/matplotlib/fontlist-v330.json
# Fix size testing.
# training chunk_sizes: [8]
# The output will be saved to  /content/FairMOT/src/lib/../../exp/mot/default
# opt.gpus:  [0]
# Setting up data...
# Dataset root: /content/FairMOT/datasetC5
# Total 8063 image files in C5_train dataset.
# dataset summary
# OrderedDict([('C5_train', defaultdict(<class 'int'>, {3: 289.0, 2: 262.0, 0: 283.0, 4: 290.0, 1: 270.0, 5: 269.0}))])
# Total 289 IDs of ManHelmetVest
# Total 262 IDs of ManVest
# Total 283 IDs of Man
# Total 290 IDs of Guard
# ...

# %% [markdown]
# # Предикт

# %%
# Загружаем тестовые видео
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1ApXds33F9I0blRnyPhLXLJy7Y02Fsn6b/view?usp=share_link&export=download
# Распаковываем 
# !unzip "/content/FairMOT/test-video.zip" -d "/content/test-video"
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1ApXds33F9I0blRnyPhLXLJy7Y02Fsn6b
# From (redirected): https://drive.google.com/uc?id=1ApXds33F9I0blRnyPhLXLJy7Y02Fsn6b&confirm=t&uuid=59fee7f5-f05e-4580-a89d-98b46b702491
# To: /content/FairMOT/test-video.zip
# 100% 143M/143M [00:02<00:00, 53.7MB/s]
# Archive:  /content/FairMOT/test-video.zip
#   inflating: /content/test-video/test/35.mp4
#   inflating: /content/test-video/test/33.mp4
#   inflating: /content/test-video/test/41.mp4
#   inflating: /content/test-video/test/37.mp4
#   inflating: /content/test-video/test/19.mp4
#   inflating: /content/test-video/test/34.mp4
#   inflating: /content/test-video/test/36.mp4
#   inflating: /content/test-video/test/32.mp4
#   inflating: /content/test-video/test/43.mp4
#   inflating: /content/test-video/test/23.mp4
#   inflating: /content/test-video/test/42.mp4
#   inflating: /content/test-video/test/31.mp4
#   inflating: /content/test-video/test/18.mp4
# ...

# %% [markdown]
# ## Загружаем обученные архитектуры

# %%
# %cd /content
# Out:
# /content

# %%
# Загружаем model_12_dla34.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1Hm1c_lO4eiNPYWy56UeT-V44h3UsxPCM/view?usp=share_link&export=download
# Последняя эпоха model_last_dla34.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HoqaPamRKbGzBCKYvj3N9yTimC4ptwG4/view?usp=share_link&export=download

# Загружаем model_15_cspdarknet53.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HdETUF62mB0C1EkKgSzn4wXIRIrSWFdJ/view?usp=share_link&export=download
# Последняя эоха model_last_cspdarknet53.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HneeU_go6Af7tKIC9Kc4jBXWGpzPuBi6/view?usp=share_link&export=download

# Загружаем model_18_yolo5s.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HZVXnFw6h1Dr9n9bGznJreixmMztvwjd/view?usp=share_link&export=download
# Последняя эпоха model_last_yolo5s.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HvT2bJCi66wRt8qjUBjOzjXM6UDugT3U/view?usp=share_link&export=download

# Загружаем model_33_resdcn18.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HhIz8kJVo1_Q74903P6_RgrlcGbSxEim/view?usp=share_link&export=download
# Последняя эпоха model_last_resdcn18.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1Hq00duSClD6ByR_XlyXZXSKQoEqKBTgf/view?usp=share_link&export=download

# Загружаем model_33_resdcn34.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HbQuOXEGgOS-GsPqJvXn1ENBwYxafixX/view?usp=share_link&export=download
# Последняя эпоха model_last_resdcn34.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1HmvAdiISpUvl0cBYHt9Rch94_mJps-ej/view?usp=share_link&export=download

# Загружаем model_60_resfpndcn34.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1H_4LOFfpxApgxu_DateMbhpB-tWGV1ty/view?usp=share_link&export=download
# Последняя эпоха model_last_resfpndcn34.pth
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1Hq__yxO690Hha3CRNH6oX-EDBx0Zg4wa/view?usp=share_link&export=download
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1Hm1c_lO4eiNPYWy56UeT-V44h3UsxPCM
# From (redirected): https://drive.google.com/uc?id=1Hm1c_lO4eiNPYWy56UeT-V44h3UsxPCM&confirm=t&uuid=427d6ab9-8f46-493a-b271-eb826572312a
# To: /content/model_12_dla34.pth
# 100% 246M/246M [00:07<00:00, 35.2MB/s]
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1HoqaPamRKbGzBCKYvj3N9yTimC4ptwG4
# From (redirected): https://drive.google.com/uc?id=1HoqaPamRKbGzBCKYvj3N9yTimC4ptwG4&confirm=t&uuid=607f02ee-bf4f-47af-908c-5d49ac72a0c2
# To: /content/model_last_dla34.pth
# 100% 246M/246M [00:06<00:00, 39.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1HdETUF62mB0C1EkKgSzn4wXIRIrSWFdJ
# To: /content/model_15_cspdarknet53.pth
# 100% 19.6M/19.6M [00:00<00:00, 30.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1HneeU_go6Af7tKIC9Kc4jBXWGpzPuBi6
# To: /content/model_last_cspdarknet53.pth
# 100% 19.6M/19.6M [00:01<00:00, 13.6MB/s]
# Downloading...
# ...

# %% [markdown]
# ## Предиктим 4 видео

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Модели до переобучения**

# %%
path_dla34 = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/dla34'
path_cspdarknet53 = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/cspdarknet53'
path_yolo = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/yolo'
path_resdcn18 = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn18'
path_resdcn34 = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn34'
path_resfpndcn34 = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resfpndcn34'

# %%
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/dla34 --arch dla_34 --load_model /content/model_12_dla34.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# Out:
# 2023-04-13 06:03:47 [INFO]: NumExpr defaulting to 2 threads.
# Fix size testing.
# training chunk_sizes: [5, 5]
# The output will be saved to  /content/FairMOT/src/lib/../../exp/mot/default
# Net input image size: 1088×608
# heads:  {'hm': 7, 'wh': 2, 'id': 128, 'reg': 2}
# 2023-04-13 06:03:47 [INFO]: Starting tracking...
# 2023-04-13 06:03:47 [INFO]: Starting tracking...
# Lenth of the video: 1392 frames
# Using gpu: 0
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# Creating model...
# loaded /content/model_12_dla34.pth, epoch 12
# 2023-04-13 06:03:57 [INFO]: Processing frame 30 (13.46 fps)
# 2023-04-13 06:03:57 [INFO]: Processing frame 30 (13.46 fps)
# 2023-04-13 06:04:02 [INFO]: Processing frame 60 (13.07 fps)
# 2023-04-13 06:04:02 [INFO]: Processing frame 60 (13.07 fps)
# 2023-04-13 06:04:07 [INFO]: Processing frame 90 (13.35 fps)
# 2023-04-13 06:04:07 [INFO]: Processing frame 90 (13.35 fps)
# ...

# %%
#%cd /content/FairMOT/src
#!python /content/FairMOT/src/demo.py --output-root path_dla34 --arch dla_34 --load_model /content/model_12_dla34.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/cspdarknet53 --arch cspdarknet_53 --load_model /content/model_15_cspdarknet53.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/yolo --arch yolo --load_model /content/model_18_yolo5s.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn18 --arch resdcn_18 --load_model /content/model_33_resdcn18.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn34 --arch resdcn_34 --load_model /content/model_33_resdcn34.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resfpndcn34 --arch resfpndcn_34 --load_model /content/model_60_resfpndcn34.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# Out:
# 2023-04-13 06:19:06 [INFO]: NumExpr defaulting to 2 threads.
# Fix size testing.
# training chunk_sizes: [5, 5]
# The output will be saved to  /content/FairMOT/src/lib/../../exp/mot/default
# Net input image size: 1088×608
# heads:  {'hm': 7, 'wh': 2, 'id': 128, 'reg': 2}
# 2023-04-13 06:19:06 [INFO]: Starting tracking...
# 2023-04-13 06:19:06 [INFO]: Starting tracking...
# Lenth of the video: 1392 frames
# Using gpu: 0
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# Creating model...
# loaded /content/model_15_cspdarknet53.pth, epoch 15
# 2023-04-13 06:19:19 [INFO]: Processing frame 30 (5.64 fps)
# 2023-04-13 06:19:19 [INFO]: Processing frame 30 (5.64 fps)
# 2023-04-13 06:19:30 [INFO]: Processing frame 60 (5.21 fps)
# 2023-04-13 06:19:30 [INFO]: Processing frame 60 (5.21 fps)
# 2023-04-13 06:19:39 [INFO]: Processing frame 90 (5.50 fps)
# 2023-04-13 06:19:39 [INFO]: Processing frame 90 (5.50 fps)
# ...

# %% [markdown]
# **Последнии модели с переобучением**

# %%
path_dla34_last = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/dla34_last'
path_cspdarknet53_last = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/cspdarknet53_last'
path_yolo_last = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/yolo_last'
path_resdcn18_last = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn18_last'
path_resdcn34_last = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn34_last'
path_resfpndcn34_last = '/content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resfpndcn34_last'

# %%
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/dla34_last --arch dla_34        --load_model /content/model_last_dla34.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/cspdarknet53_last --arch cspdarknet_53 --load_model /content/model_last_cspdarknet53.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/yolo_last --arch yolo          --load_model /content/model_last_yolo5s.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn18_last --arch resdcn_18     --load_model /content/model_last_resdcn18.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resdcn34_last --arch resdcn_34     --load_model /content/model_last_resdcn34.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# !python /content/FairMOT/src/demo.py --output-root /content/drive/MyDrive/Самолёт_2/MOT_CapitanEval/predict_video/results/resfpndcn34_last --arch resfpndcn_34  --load_model /content/model_last_resfpndcn34.pth --conf_thres 0.1 --input-video /content/test-video/test/4.mp4
# Out:
# 2023-04-13 06:47:16 [INFO]: NumExpr defaulting to 2 threads.
# Fix size testing.
# training chunk_sizes: [5, 5]
# The output will be saved to  /content/FairMOT/src/lib/../../exp/mot/default
# Net input image size: 1088×608
# heads:  {'hm': 7, 'wh': 2, 'id': 128, 'reg': 2}
# 2023-04-13 06:47:16 [INFO]: Starting tracking...
# 2023-04-13 06:47:16 [INFO]: Starting tracking...
# Lenth of the video: 1392 frames
# Using gpu: 0
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# Creating model...
# loaded /content/model_last_dla34.pth, epoch 30
# 2023-04-13 06:47:25 [INFO]: Processing frame 30 (14.30 fps)
# 2023-04-13 06:47:25 [INFO]: Processing frame 30 (14.30 fps)
# 2023-04-13 06:47:31 [INFO]: Processing frame 60 (13.85 fps)
# 2023-04-13 06:47:31 [INFO]: Processing frame 60 (13.85 fps)
# 2023-04-13 06:47:36 [INFO]: Processing frame 90 (14.11 fps)
# 2023-04-13 06:47:36 [INFO]: Processing frame 90 (14.11 fps)
# ...
